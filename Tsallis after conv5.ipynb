# %%
 from __future__ import print_function
import tensorflow as tf
import os
import import_ipynb
from skimage.transform import resize
from skimage.io import imsave
from data import load_test_data , load_train_data

import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, concatenate, Conv2D, MaxPooling2D, Conv2DTranspose,Dense , Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K
from tensorflow.keras.activations import softmax
 
 
 
 
K.set_image_data_format('channels_last')  # TF dimension ordering in this code
 
img_rows = 96
img_cols = 96
 
smooth = 1.



def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    
 
 
def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)
 
def get_unet():
    inputs = Input((img_rows, img_cols, 1))
    print("++++++++++++++++++++++++++++++++++++++++++++++new Line")
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    print("dim",conv1.shape)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    print("dim",conv1.shape)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    print("dim",pool1.shape)
    pool1 = Dropout(0.5)(pool1)
    print("dim",pool1.shape)
        
        
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    print('dim',conv2.shape)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    print('dim',conv2.shape)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    print('dim',pool2.shape)
    pool2 = Dropout(0.5)(pool2)
    print('dim',pool2.shape)


    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    print('dim',conv3.shape)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    print('dim',conv3.shape)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    print('dim',pool3.shape)
    pool3 = Dropout(0.5)(pool3)
    print('dim',pool3.shape)
 
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    print('dim',conv4.shape)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    print('dim',conv4.shape)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    print('dim',pool4.shape)
    pool4 = Dropout(0.5)(pool4)
    print('dim',pool4.shape)
    
    
 
    
    ##################################
    
#     n=tx.shape[0]
#     temp=tf.zeros([0,0],tf.float32)
    
#     for i in range(n):
#         print("=========inside loop",i)
#         safe_x = K.maximum(tx[i],1e-6)
#         new_p = K.switch(K.equal(q,1.), K.log(safe_x),(K.pow(safe_x,q))/(q-1))
#         new_p = -new_p #-p^q/(q-1)
    
    
#         new_p= 1+new_p
#         weights=1-(new_p/K.max(new_p))
    
#         improved_p=td[i]*weights
        
#         temp=tf.concat([temp,(K.sum(improved_p)/144)],0)
    
    
    
    
#     dense_nodes=K.reshape(K.variable(temp),shape=(1,256))
#     print(dense_nodes.shape)
    ####
#     den=[]
#     for i in range(n):
#         den.append(tf.reduce_sum(before_gap[i])/144)
    
    
#    dense_nodes=tf.Variable(den)
#     dense_nodes=tf.reshape(dense_nodes,shape=(1,256))
    
#     dense_nodes=K.sum(before_gap,axis=1)/144.0
#     print(dense_nodes.shape)
#     dense_nodes=K.reshape(before_gap,shape=(1,256))
    
    
#     print("temp type=",type(temp[0]))
#     dense_nodes = tf. convert_to_tensor(improved_p)
#     print("dense node=",dense_nodes)
#     xy=tf.reshape(dense_nodes,(1,256))
#     print("xy=",xy)
    #improved_p=tf.reshape(improved_p,(1,256))
    
    #############################
    
    
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    print('dim',conv5.shape)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)
    print('dim',conv5.shape)
    conv5 = Dropout(0.5)(conv5)
    print('dim',conv5.shape)
    
    print(tf.shape(conv5))
    td=conv5
    
    tx=softmax(td,axis=[1,2])
    q=1.25
    
    
    print("value of q",q)
    
    
    
    safe_x = K.maximum(tx,1e-6)
    new_p = K.switch(K.equal(q,1.), (K.log(safe_x)*safe_x)/K.log(2.718),(K.pow(safe_x,q))/(q-1))
    new_p = -new_p #-p^q/(q-1)
    
    if q!=1:
        new_p= 1+new_p
        
    print("new_p",new_p.shape)
    xyz=K.max(new_p,axis=[1,2],keepdims=True)
    print("xyz=",xyz.shape)
   
    
    print("xyz=",xyz.shape)
    weights=1-(new_p/xyz)
    print("weights",weights.shape)
    improved_p=td*weights
    print("improved_p=",improved_p.shape)
    improved_p=K.sum(improved_p,axis=[1,2])/36
    print("improved_pv2=",type(improved_p),improved_p.shape)
    
    dense1=Dense(32,activation='relu')(improved_p)
    print("dense1",dense1)
    dense2=Dense(1,activation='softmax')(dense1)
    print("below dense",dense2)
    
    
    
 
    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    print('dim',up6.shape)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    print('dim',conv6.shape)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)
    
    print('dim',conv6.shape)
    conv6 = Dropout(0.5)(conv6)
    print('dim',conv6.shape)
 
    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    print('dim',up7.shape)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    print('dim',conv7.shape)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)
    print('dim',conv7.shape)
    conv7 = Dropout(0.5)(conv7)
    print('dim',conv7.shape)
 
    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    print('dim',up8.shape)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    print('dim',conv8.shape)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)
    print('dim',conv8.shape)
    conv8 = Dropout(0.5)(conv8)
    print('dim',conv8.shape)
 
    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    print('dim',up9.shape)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    print('dim',conv9.shape)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)
    print('dim',conv9.shape)
    conv9 = Dropout(0.5)(conv9)
    print('dim',conv9.shape)
 
    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)
    print("dim", conv10.shape) 
 
    model = Model(inputs=[inputs], outputs=[conv10,dense2])
 
    model.compile(optimizer=Adam(learning_rate=1e-5), loss=[dice_coef_loss,tf.keras.losses.BinaryCrossentropy()],
                  metrics=[dice_coef,tf.keras.metrics.BinaryCrossentropy()])
 
    return model
 
def preprocess(imgs):
    imgs_p = np.ndarray((imgs.shape[0], img_rows, img_cols), dtype=np.uint8)
    for i in range(imgs.shape[0]):
        imgs_p[i] = resize(imgs[i], (img_cols, img_rows), preserve_range=True)
 
    imgs_p = imgs_p[..., np.newaxis]
    return imgs_p
 
def train_and_predict():
    imgs_train,imgs_mask_train,imgs_value_train=load_train_data()
 
    imgs_train = preprocess(imgs_train)
    imgs_mask_train = preprocess(imgs_mask_train)
 
    imgs_train = imgs_train.astype('float32')
    mean = np.mean(imgs_train)  # mean for data centering
    std = np.std(imgs_train)  # std for data normalization
 
    imgs_train -= mean
    imgs_train /= std
 
    imgs_mask_train = imgs_mask_train.astype('float32')
    imgs_mask_train /= 255.  # scale masks to [0, 1]
 
    print('-'*30)
    print('Creating and compiling model...')
    print('-'*30)
    model = get_unet()
    model_checkpoint = ModelCheckpoint('weights.h5', monitor='val_loss' , mode = 'min' , verbose = 1 , save_best_only=True )
 
    print('-'*30)
    print('Fitting model...')
    print('-'*30)
    model.fit(imgs_train, y=[imgs_mask_train,imgs_value_train], batch_size=32, epochs= 20, verbose=1, shuffle=True,
              validation_split=0.2 ,  callbacks=[model_checkpoint])
    
    print('-'*30)
    print('Loading and preprocessing test data...')
    print('-'*30)
    imgs_test, imgs_id_test = load_test_data()
    imgs_test = preprocess(imgs_test)

    imgs_test = imgs_test.astype('float32')
    imgs_test -= mean
    imgs_test /= std

    print('-'*30)
    print('Loading saved weights...')
    print('-'*30)
    model.load_weights('weights.h5')

    print('-'*30)
    print('Predicting masks on test data...')
    print('-'*30)
    n_imgs_test = imgs_test.shape[0]
    #for i in range(n_imgs_test):

    #worked for 7 vs 1
    #imgs_mask_test, imgs_value_test= model.predict(np.expand_dims(imgs_test[0] , axis = 0), verbose=1)


    imgs_mask_test, imgs_value_test= model.predict(imgs_test, verbose=1)
    print("mask final img 1" , imgs_mask_test)
    np.save('imgs_mask_test.npy', imgs_mask_test)

    print('-' * 30)
    print('Saving predicted masks to files...')
    print('-' * 30)
    pred_dir = 'preds'
    
    # print(imgs_mask_test.shape , imgs_value_test.shape)
    if not os.path.exists(pred_dir):
        os.mkdir(pred_dir)
    for image, image_id in zip(imgs_mask_test, imgs_id_test):
        image = (image[:, :, 0] * 255.).astype(np.uint8)
        imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)


 
     
if __name__ == '__main__':
    train_and_predict()
# Out:
# importing Jupyter notebook from data.ipynb
# ------------------------------
# Creating and compiling model...
# ------------------------------
# ++++++++++++++++++++++++++++++++++++++++++++++new Line
# dim (None, 96, 96, 32)
# dim (None, 96, 96, 32)
# dim (None, 48, 48, 32)
# dim (None, 48, 48, 32)
# dim (None, 48, 48, 64)
# dim (None, 48, 48, 64)
# dim (None, 24, 24, 64)
# dim (None, 24, 24, 64)
# dim (None, 24, 24, 128)
# dim (None, 24, 24, 128)
# dim (None, 12, 12, 128)
# dim (None, 12, 12, 128)
# dim (None, 12, 12, 256)
# dim (None, 12, 12, 256)
# dim (None, 6, 6, 256)
# dim (None, 6, 6, 256)
# dim (None, 6, 6, 512)
# dim (None, 6, 6, 512)
# dim (None, 6, 6, 512)
# KerasTensor(type_spec=TensorSpec(shape=(4,), dtype=tf.int32, name=None), inferred_value=[None, 6, 6, 512], name='tf.compat.v1.shape/Shape:0', description="created by layer 'tf.compat.v1.shape'")
# value of q 1.25
# new_p (None, 6, 6, 512)
# xyz= (None, 1, 1, 512)
# xyz= (None, 1, 1, 512)
# weights (None, 6, 6, 512)
# improved_p= (None, 6, 6, 512)
# improved_pv2= <class 'tensorflow.python.keras.engine.keras_tensor.KerasTensor'> (None, 512)
# dense1 KerasTensor(type_spec=TensorSpec(shape=(None, 32), dtype=tf.float32, name=None), name='dense/Relu:0', description="created by layer 'dense'")
# below dense KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='dense_1/Softmax:0', description="created by layer 'dense_1'")
# dim (None, 12, 12, 512)
# dim (None, 12, 12, 256)
# dim (None, 12, 12, 256)
# dim (None, 12, 12, 256)
# dim (None, 24, 24, 256)
# dim (None, 24, 24, 128)
# dim (None, 24, 24, 128)
# dim (None, 24, 24, 128)
# dim (None, 48, 48, 128)
# dim (None, 48, 48, 64)
# dim (None, 48, 48, 64)
# dim (None, 48, 48, 64)
# dim (None, 96, 96, 64)
# dim (None, 96, 96, 32)
# dim (None, 96, 96, 32)
# dim (None, 96, 96, 32)
# dim (None, 96, 96, 1)
# ------------------------------
# Fitting model...
# ------------------------------
# Epoch 1/20
# 141/141 [==============================] - 41s 208ms/step - loss: 0.6660 - conv2d_18_loss: -0.0250 - dense_1_loss: 0.6911 - conv2d_18_dice_coef: 0.0250 - conv2d_18_binary_crossentropy: 0.7539 - dense_1_dice_coef: 0.6091 - dense_1_binary_crossentropy: 0.6911 - val_loss: 0.6728 - val_conv2d_18_loss: -0.0195 - val_dense_1_loss: 0.6923 - val_conv2d_18_dice_coef: 0.0196 - val_conv2d_18_binary_crossentropy: 0.7820 - val_dense_1_dice_coef: 0.4727 - val_dense_1_binary_crossentropy: 0.6923
#
# Epoch 00001: val_loss improved from inf to 0.67278, saving model to weights.h5
# Epoch 2/20
# 141/141 [==============================] - 24s 170ms/step - loss: 0.6600 - conv2d_18_loss: -0.0287 - dense_1_loss: 0.6886 - conv2d_18_dice_coef: 0.0287 - conv2d_18_binary_crossentropy: 1.3477 - dense_1_dice_coef: 0.6099 - dense_1_binary_crossentropy: 0.6886 - val_loss: 0.6712 - val_conv2d_18_loss: -0.0208 - val_dense_1_loss: 0.6920 - val_conv2d_18_dice_coef: 0.0209 - val_conv2d_18_binary_crossentropy: 0.7589 - val_dense_1_dice_coef: 0.4727 - val_dense_1_binary_crossentropy: 0.6920
#
# Epoch 00002: val_loss improved from 0.67278 to 0.67122, saving model to weights.h5
# Epoch 3/20
# 141/141 [==============================] - 24s 169ms/step - loss: 0.6501 - conv2d_18_loss: -0.0380 - dense_1_loss: 0.6882 - conv2d_18_dice_coef: 0.0380 - conv2d_18_binary_crossentropy: 1.2968 - dense_1_dice_coef: 0.6099 - dense_1_binary_crossentropy: 0.6882 - val_loss: 0.6648 - val_conv2d_18_loss: -0.0268 - val_dense_1_loss: 0.6916 - val_conv2d_18_dice_coef: 0.0272 - val_conv2d_18_binary_crossentropy: 0.6746 - val_dense_1_dice_coef: 0.4727 - val_dense_1_binary_crossentropy: 0.6916
#
# Epoch 00003: val_loss improved from 0.67122 to 0.66478, saving model to weights.h5
# Epoch 4/20
# 141/141 [==============================] - 24s 169ms/step - loss: 0.5831 - conv2d_18_loss: -0.1051 - dense_1_loss: 0.6883 - conv2d_18_dice_coef: 0.1052 - conv2d_18_binary_crossentropy: 1.6603 - dense_1_dice_coef: 0.6096 - dense_1_binary_crossentropy: 0.6883 - val_loss: 0.5749 - val_conv2d_18_loss: -0.1156 - val_dense_1_loss: 0.6905 - val_conv2d_18_dice_coef: 0.1168 - val_conv2d_18_binary_crossentropy: 1.5440 - val_dense_1_dice_coef: 0.4727 - val_dense_1_binary_crossentropy: 0.6905
#
# Epoch 00004: val_loss improved from 0.66478 to 0.57491, saving model to weights.h5
# Epoch 5/20
# 141/141 [==============================] - 24s 170ms/step - loss: 0.4648 - conv2d_18_loss: -0.2215 - dense_1_loss: 0.6863 - conv2d_18_dice_coef: 0.2215 - conv2d_18_binary_crossentropy: 1.2630 - dense_1_dice_coef: 0.6093 - dense_1_binary_crossentropy: 0.6863 - val_loss: 0.5319 - val_conv2d_18_loss: -0.1590 - val_dense_1_loss: 0.6910 - val_conv2d_18_dice_coef: 0.1618 - val_conv2d_18_binary_crossentropy: 0.5270 - val_dense_1_dice_coef: 0.4727 - val_dense_1_binary_crossentropy: 0.6910
#
# Epoch 00005: val_loss improved from 0.57491 to 0.53191, saving model to weights.h5
# Epoch 6/20
# 141/141 [==============================] - 24s 174ms/step - loss: 0.4540 - conv2d_18_loss: -0.2291 - dense_1_loss: 0.6832 - conv2d_18_dice_coef: 0.2292 - conv2d_18_binary_crossentropy: 1.3795 - dense_1_dice_coef: 0.6091 - dense_1_binary_crossentropy: 0.6832 - val_loss: 0.5206 - val_conv2d_18_loss: -0.1693 - val_dense_1_loss: 0.6898 - val_conv2d_18_dice_coef: 0.1723 - val_conv2d_18_binary_crossentropy: 0.5660 - val_dense_1_dice_coef: 0.4727 - val_dense_1_binary_crossentropy: 0.6898
#
# Epoch 00006: val_loss improved from 0.53191 to 0.52056, saving model to weights.h5
# Epoch 7/20
# 141/141 [==============================] - 24s 170ms/step - loss: 0.4268 - conv2d_18_loss: -0.2537 - dense_1_loss: 0.6805 - conv2d_18_dice_coef: 0.2537 - conv2d_18_binary_crossentropy: 1.2061 - dense_1_dice_coef: 0.6100 - dense_1_binary_crossentropy: 0.6805 - val_loss: 0.5399 - val_conv2d_18_loss: -0.1488 - val_dense_1_loss: 0.6887 - val_conv2d_18_dice_coef: 0.1507 - val_conv2d_18_binary_crossentropy: 1.1952 - val_dense_1_dice_coef: 0.4727 - val_dense_1_binary_crossentropy: 0.6887
#
# Epoch 00007: val_loss did not improve from 0.52056
# Epoch 8/20
# 141/141 [==============================] - 24s 169ms/step - loss: 0.4127 - conv2d_18_loss: -0.2629 - dense_1_loss: 0.6756 - conv2d_18_dice_coef: 0.2630 - conv2d_18_binary_crossentropy: 1.4121 - dense_1_dice_coef: 0.6097 - dense_1_binary_crossentropy: 0.6756 - val_loss: 0.5342 - val_conv2d_18_loss: -0.1527 - val_dense_1_loss: 0.6869 - val_conv2d_18_dice_coef: 0.1544 - val_conv2d_18_binary_crossentropy: 1.2920 - val_dense_1_dice_coef: 0.4727 - val_dense_1_binary_crossentropy: 0.6869
#
# Epoch 00008: val_loss did not improve from 0.52056
# Epoch 9/20
# 141/141 [==============================] - 24s 170ms/step - loss: 0.3972 - conv2d_18_loss: -0.2744 - dense_1_loss: 0.6715 - conv2d_18_dice_coef: 0.2744 - conv2d_18_binary_crossentropy: 1.3944 - dense_1_dice_coef: 0.6089 - dense_1_binary_crossentropy: 0.6715 - val_loss: 0.5093 - val_conv2d_18_loss: -0.1759 - val_dense_1_loss: 0.6852 - val_conv2d_18_dice_coef: 0.1779 - val_conv2d_18_binary_crossentropy: 0.9446 - val_dense_1_dice_coef: 0.4727 - val_dense_1_binary_crossentropy: 0.6852
#
# Epoch 00009: val_loss improved from 0.52056 to 0.50926, saving model to weights.h5
# Epoch 10/20
# 141/141 [==============================] - 24s 169ms/step - loss: 0.3762 - conv2d_18_loss: -0.2896 - dense_1_loss: 0.6658 - conv2d_18_dice_coef: 0.2896 - conv2d_18_binary_crossentropy: 1.3807 - dense_1_dice_coef: 0.6093 - dense_1_binary_crossentropy: 0.6658 - val_loss: 0.5075 - val_conv2d_18_loss: -0.1750 - val_dense_1_loss: 0.6825 - val_conv2d_18_dice_coef: 0.1762 - val_conv2d_18_binary_crossentropy: 1.3236 - val_dense_1_dice_coef: 0.4727 - val_dense_1_binary_crossentropy: 0.6825
#
# Epoch 00010: val_loss improved from 0.50926 to 0.50754, saving model to weights.h5
# Epoch 11/20
# 141/141 [==============================] - 24s 169ms/step - loss: 0.3652 - conv2d_18_loss: -0.2967 - dense_1_loss: 0.6619 - conv2d_18_dice_coef: 0.2968 - conv2d_18_binary_crossentropy: 1.6966 - dense_1_dice_coef: 0.6091 - dense_1_binary_crossentropy: 0.6619 - val_loss: 0.5214 - val_conv2d_18_loss: -0.1596 - val_dense_1_loss: 0.6810 - val_conv2d_18_dice_coef: 0.1604 - val_conv2d_18_binary_crossentropy: 1.9325 - val_dense_1_dice_coef: 0.4727 - val_dense_1_binary_crossentropy: 0.6810
#
# Epoch 00011: val_loss did not improve from 0.50754
# Epoch 12/20
# 141/141 [==============================] - 24s 170ms/step - loss: 0.3367 - conv2d_18_loss: -0.3190 - dense_1_loss: 0.6558 - conv2d_18_dice_coef: 0.3190 - conv2d_18_binary_crossentropy: 1.3363 - dense_1_dice_coef: 0.6101 - dense_1_binary_crossentropy: 0.6558 - val_loss: 0.5173 - val_conv2d_18_loss: -0.1588 - val_dense_1_loss: 0.6761 - val_conv2d_18_dice_coef: 0.1593 - val_conv2d_18_binary_crossentropy: 2.2332 - val_dense_1_dice_coef: 0.4727 - val_dense_1_binary_crossentropy: 0.6761
#
# Epoch 00012: val_loss did not improve from 0.50754
# Epoch 13/20
# 141/141 [==============================] - 24s 170ms/step - loss: 0.3061 - conv2d_18_loss: -0.3351 - dense_1_loss: 0.6412 - conv2d_18_dice_coef: 0.3351 - conv2d_18_binary_crossentropy: 1.3971 - dense_1_dice_coef: 0.6087 - dense_1_binary_crossentropy: 0.6412 - val_loss: 0.5061 - val_conv2d_18_loss: -0.1669 - val_dense_1_loss: 0.6730 - val_conv2d_18_dice_coef: 0.1673 - val_conv2d_18_binary_crossentropy: 2.3475 - val_dense_1_dice_coef: 0.4727 - val_dense_1_binary_crossentropy: 0.6730
#
# Epoch 00013: val_loss improved from 0.50754 to 0.50611, saving model to weights.h5
# Epoch 14/20
# 141/141 [==============================] - 24s 169ms/step - loss: 0.2912 - conv2d_18_loss: -0.3495 - dense_1_loss: 0.6407 - conv2d_18_dice_coef: 0.3496 - conv2d_18_binary_crossentropy: 1.2035 - dense_1_dice_coef: 0.6082 - dense_1_binary_crossentropy: 0.6407 - val_loss: 0.4614 - val_conv2d_18_loss: -0.2084 - val_dense_1_loss: 0.6698 - val_conv2d_18_dice_coef: 0.2088 - val_conv2d_18_binary_crossentropy: 1.2945 - val_dense_1_dice_coef: 0.4727 - val_dense_1_binary_crossentropy: 0.6698
#
# Epoch 00014: val_loss improved from 0.50611 to 0.46143, saving model to weights.h5
# Epoch 15/20
# 141/141 [==============================] - 24s 170ms/step - loss: 0.2682 - conv2d_18_loss: -0.3670 - dense_1_loss: 0.6352 - conv2d_18_dice_coef: 0.3670 - conv2d_18_binary_crossentropy: 1.1118 - dense_1_dice_coef: 0.6087 - dense_1_binary_crossentropy: 0.6352 - val_loss: 0.4367 - val_conv2d_18_loss: -0.2300 - val_dense_1_loss: 0.6667 - val_conv2d_18_dice_coef: 0.2310 - val_conv2d_18_binary_crossentropy: 1.1189 - val_dense_1_dice_coef: 0.4727 - val_dense_1_binary_crossentropy: 0.6667
#
# Epoch 00015: val_loss improved from 0.46143 to 0.43670, saving model to weights.h5
# Epoch 16/20
# 141/141 [==============================] - 24s 169ms/step - loss: 0.2506 - conv2d_18_loss: -0.3837 - dense_1_loss: 0.6343 - conv2d_18_dice_coef: 0.3836 - conv2d_18_binary_crossentropy: 0.9747 - dense_1_dice_coef: 0.6102 - dense_1_binary_crossentropy: 0.6343 - val_loss: 0.4436 - val_conv2d_18_loss: -0.2244 - val_dense_1_loss: 0.6680 - val_conv2d_18_dice_coef: 0.2252 - val_conv2d_18_binary_crossentropy: 1.1335 - val_dense_1_dice_coef: 0.4727 - val_dense_1_binary_crossentropy: 0.6680
#
# Epoch 00016: val_loss did not improve from 0.43670
# Epoch 17/20
# 141/141 [==============================] - 24s 170ms/step - loss: 0.2354 - conv2d_18_loss: -0.3977 - dense_1_loss: 0.6331 - conv2d_18_dice_coef: 0.3977 - conv2d_18_binary_crossentropy: 0.8573 - dense_1_dice_coef: 0.6100 - dense_1_binary_crossentropy: 0.6331 - val_loss: 0.4449 - val_conv2d_18_loss: -0.2227 - val_dense_1_loss: 0.6676 - val_conv2d_18_dice_coef: 0.2234 - val_conv2d_18_binary_crossentropy: 1.2386 - val_dense_1_dice_coef: 0.4727 - val_dense_1_binary_crossentropy: 0.6676
#
# Epoch 00017: val_loss did not improve from 0.43670
# Epoch 18/20
# 141/141 [==============================] - 24s 170ms/step - loss: 0.2279 - conv2d_18_loss: -0.4036 - dense_1_loss: 0.6316 - conv2d_18_dice_coef: 0.4036 - conv2d_18_binary_crossentropy: 0.8476 - dense_1_dice_coef: 0.6090 - dense_1_binary_crossentropy: 0.6316 - val_loss: 0.4325 - val_conv2d_18_loss: -0.2329 - val_dense_1_loss: 0.6654 - val_conv2d_18_dice_coef: 0.2338 - val_conv2d_18_binary_crossentropy: 1.1047 - val_dense_1_dice_coef: 0.4727 - val_dense_1_binary_crossentropy: 0.6654
#
# Epoch 00018: val_loss improved from 0.43670 to 0.43253, saving model to weights.h5
# Epoch 19/20
# 141/141 [==============================] - 24s 169ms/step - loss: 0.2107 - conv2d_18_loss: -0.4152 - dense_1_loss: 0.6259 - conv2d_18_dice_coef: 0.4152 - conv2d_18_binary_crossentropy: 0.8071 - dense_1_dice_coef: 0.6092 - dense_1_binary_crossentropy: 0.6259 - val_loss: 0.4346 - val_conv2d_18_loss: -0.2295 - val_dense_1_loss: 0.6641 - val_conv2d_18_dice_coef: 0.2305 - val_conv2d_18_binary_crossentropy: 1.2575 - val_dense_1_dice_coef: 0.4727 - val_dense_1_binary_crossentropy: 0.6641
#
# Epoch 00019: val_loss did not improve from 0.43253
# Epoch 20/20
# 141/141 [==============================] - 25s 179ms/step - loss: 0.1928 - conv2d_18_loss: -0.4248 - dense_1_loss: 0.6177 - conv2d_18_dice_coef: 0.4248 - conv2d_18_binary_crossentropy: 0.8187 - dense_1_dice_coef: 0.6094 - dense_1_binary_crossentropy: 0.6177 - val_loss: 0.4106 - val_conv2d_18_loss: -0.2534 - val_dense_1_loss: 0.6640 - val_conv2d_18_dice_coef: 0.2551 - val_conv2d_18_binary_crossentropy: 1.0867 - val_dense_1_dice_coef: 0.4727 - val_dense_1_binary_crossentropy: 0.6640
#
# Epoch 00020: val_loss improved from 0.43253 to 0.41055, saving model to weights.h5
# ------------------------------
# Loading and preprocessing test data...
# ------------------------------
# ------------------------------
# Loading saved weights...
# ------------------------------
# ------------------------------
# Predicting masks on test data...
# ------------------------------
# 173/173 [==============================] - 9s 48ms/step
# mask final img 1 [[[[6.38787225e-02]
#    [9.44425352e-03]
#    [1.25073467e-03]
#    ...
#    [4.29938167e-01]
#    [3.80062580e-01]
#    [4.94398236e-01]]
#
#   [[4.85353731e-03]
#    [1.08571541e-04]
#    [1.91172376e-06]
#    ...
#    [3.74297857e-01]
#    [3.91834050e-01]
#    [3.97466332e-01]]
#
#   [[6.55627577e-04]
#    [1.27049805e-06]
#    [2.34597479e-08]
#    ...
#    [2.13211402e-01]
#    [1.49335727e-01]
#    [2.40702629e-01]]
#
#   ...
#
#   [[1.91341154e-03]
#    [1.82894255e-05]
#    [6.97347332e-07]
#    ...
#    [1.11668030e-09]
#    [2.62028095e-07]
#    [2.50664511e-04]]
#
#   [[7.84021709e-03]
#    [1.94957523e-04]
#    [2.50373778e-05]
#    ...
#    [9.97183136e-08]
#    [9.05859179e-06]
#    [1.54529850e-03]]
#
#   [[5.37521020e-02]
#    [6.53066160e-03]
#    [2.07864679e-03]
#    ...
#    [1.01814236e-04]
#    [1.58539228e-03]
#    [3.05295121e-02]]]
#
#
#  [[[1.32496217e-02]
#    [4.92615334e-04]
#    [1.53246001e-05]
#    ...
#    [8.03560484e-04]
#    [3.30552505e-03]
#    [4.43741903e-02]]
#
#   [[1.51056927e-04]
#    [2.32545318e-07]
#    [1.95619285e-10]
#    ...
#    [2.05082529e-06]
#    [2.05377328e-05]
#    [2.91966042e-03]]
#
#   [[4.94919323e-06]
#    [1.26644084e-10]
#    [9.64329189e-14]
#    ...
#    [4.28088542e-09]
#    [5.78076083e-07]
#    [3.66548833e-04]]
#
#   ...
#
#   [[1.03178471e-01]
#    [5.65933958e-02]
#    [5.56093976e-02]
#    ...
#    [6.04869056e-05]
#    [7.66088022e-04]
#    [1.88187920e-02]]
#
#   [[1.73459172e-01]
#    [6.66053146e-02]
#    [5.10516576e-02]
#    ...
#    [4.43602912e-04]
#    [3.67771229e-03]
#    [4.12559062e-02]]
#
#   [[2.46510431e-01]
#    [1.98355570e-01]
#    [1.51683077e-01]
#    ...
#    [1.13177020e-02]
#    [4.17240895e-02]
#    [1.52073979e-01]]]
#
#
#  [[[1.58458993e-01]
#    [4.97177839e-02]
#    [1.45946015e-02]
#    ...
#    [1.11946281e-06]
#    [1.58899093e-05]
#    [2.52057659e-03]]
#
#   [[3.26339938e-02]
#    [2.85904924e-03]
#    [2.10298138e-04]
#    ...
#    [8.91313759e-12]
#    [6.16193319e-10]
#    [1.10945530e-05]]
#
#   [[9.20765195e-03]
#    [1.72145898e-04]
#    [1.27141138e-05]
#    ...
#    [1.04705541e-16]
#    [9.42810717e-13]
#    [2.17215685e-07]]
#
#   ...
#
#   [[1.99049842e-02]
#    [1.17930316e-03]
#    [1.62978962e-04]
#    ...
#    [5.18067136e-05]
#    [6.56749529e-04]
#    [1.72763336e-02]]
#
#   [[4.58970256e-02]
#    [5.01114503e-03]
#    [1.43181579e-03]
#    ...
#    [3.91224021e-04]
#    [3.26880557e-03]
#    [3.85135002e-02]]
#
#   [[1.41107336e-01]
#    [4.19169031e-02]
#    [2.12485865e-02]
#    ...
#    [1.05101811e-02]
#    [3.89285833e-02]
#    [1.46999851e-01]]]
#
#
#  ...
#
#
#  [[[1.58048660e-01]
#    [5.50536886e-02]
#    [1.72385760e-02]
#    ...
#    [3.44261425e-05]
#    [2.42412571e-04]
#    [1.08965645e-02]]
#
#   [[3.85885090e-02]
#    [3.76833556e-03]
#    [3.66581138e-04]
#    ...
#    [6.00298344e-09]
#    [1.33939537e-07]
#    [1.95394474e-04]]
#
#   [[1.07111661e-02]
#    [2.47047661e-04]
#    [2.10504604e-05]
#    ...
#    [9.42857337e-13]
#    [8.72734107e-10]
#    [9.44467320e-06]]
#
#   ...
#
#   [[4.39726609e-05]
#    [2.50004124e-08]
#    [1.46862647e-10]
#    ...
#    [5.65474556e-06]
#    [8.52107696e-05]
#    [5.13943797e-03]]
#
#   [[5.11474092e-04]
#    [1.34266202e-06]
#    [6.02927486e-08]
#    ...
#    [6.83716644e-05]
#    [7.62361102e-04]
#    [1.56488568e-02]]
#
#   [[1.09218387e-02]
#    [3.56609555e-04]
#    [6.23796586e-05]
#    ...
#    [3.84873245e-03]
#    [1.58751104e-02]
#    [9.38001126e-02]]]
#
#
#  [[[1.20588448e-02]
#    [3.92629154e-04]
#    [1.25831875e-05]
#    ...
#    [3.03747918e-04]
#    [1.46883435e-03]
#    [2.84734704e-02]]
#
#   [[1.11989189e-04]
#    [1.60349430e-07]
#    [1.32958006e-10]
#    ...
#    [2.82946218e-07]
#    [3.49391712e-06]
#    [1.16538280e-03]]
#
#   [[3.95307688e-06]
#    [9.32254204e-11]
#    [9.81890825e-14]
#    ...
#    [2.39544301e-10]
#    [5.95381699e-08]
#    [9.68245004e-05]]
#
#   ...
#
#   [[4.88893650e-02]
#    [5.62434969e-03]
#    [1.18102203e-03]
#    ...
#    [9.17777783e-08]
#    [6.17770593e-06]
#    [1.37401070e-03]]
#
#   [[9.10174623e-02]
#    [1.70907080e-02]
#    [6.43834658e-03]
#    ...
#    [3.02807734e-06]
#    [9.83533319e-05]
#    [5.73326601e-03]]
#
#   [[2.00380132e-01]
#    [8.24615955e-02]
#    [4.92666401e-02]
#    ...
#    [6.82500249e-04]
#    [5.88413328e-03]
#    [5.89875877e-02]]]
#
#
#  [[[1.28814830e-02]
#    [4.23572288e-04]
#    [1.67411272e-05]
#    ...
#    [8.13998282e-03]
#    [1.86971370e-02]
#    [1.06468976e-01]]
#
#   [[1.23801889e-04]
#    [2.23190298e-07]
#    [2.77137369e-10]
#    ...
#    [1.35241818e-04]
#    [5.38033084e-04]
#    [1.57115310e-02]]
#
#   [[6.47501156e-06]
#    [2.19301868e-10]
#    [4.38985762e-13]
#    ...
#    [1.58726959e-06]
#    [3.61052771e-05]
#    [3.08925728e-03]]
#
#   ...
#
#   [[1.65795442e-02]
#    [8.63771536e-04]
#    [1.20342971e-04]
#    ...
#    [1.69152895e-06]
#    [5.33256971e-05]
#    [4.44468111e-03]]
#
#   [[4.02071141e-02]
#    [3.88948340e-03]
#    [1.15386024e-03]
#    ...
#    [2.71493645e-05]
#    [4.80745424e-04]
#    [1.36273913e-02]]
#
#   [[1.31388098e-01]
#    [3.67076099e-02]
#    [1.88857485e-02]
#    ...
#    [2.33207643e-03]
#    [1.39317093e-02]
#    [8.97077695e-02]]]]
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\1038_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\113_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\1258_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\1342_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\1348_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\1414_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\1492_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\1564_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\1581_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\1609_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\1628_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\1639_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\1691_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\1791_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\1918_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\208_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\2138_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\2148_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\2388_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\239_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\2438_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\2457_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\2469_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\2602_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\2664_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\2678_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\2686_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\2711_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\2720_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\2800_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\284_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\2958_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\2977_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\3047_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\313_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\3153_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\3154_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\3215_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\3262_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\3322_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\3376_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\3377_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\3486_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\3523_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\3668_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\3871_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\3950_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\3972_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4024_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4048_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4085_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4112_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4143_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4151_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4170_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4196_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4205_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4206_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4224_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4277_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4290_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4341_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4356_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4366_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4385_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4399_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4436_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4456_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4537_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4618_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4636_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4667_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4696_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4739_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4816_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4887_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4955_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\4996_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\5040_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\5044_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\5053_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\506_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\5163_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\5180_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\5199_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\5241_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\5253_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\5259_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\5284_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\5328_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\5372_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\5392_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\5504_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\585_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\630_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\670_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\735_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\851_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
# <ipython-input-1-8da897cadc1e>:300: UserWarning: preds\950_pred.png is a low contrast image
#   imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)

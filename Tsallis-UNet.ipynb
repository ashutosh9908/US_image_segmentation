# %%
import tensorflow as tf

print("Num of GPUs available:",len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num of GPUs available: 1

# %%
import matplotlib.pyplot as plt

x=[0.25,0.5,0.75,1.0,1.25,1.50,1.75]
y=[0.39140,0.39375,0.43505,0.41463,0.36531,0.36428,0.37742]

x1=[1.25,1.30,1.35,1.40,1.45,1.50,1.55,1.60,1.65,1.70,1.75]
y1=[0.36531,0.35025,0.35930,0.36634,0.36979,0.36428,0.37358,0.37159,0.37180,0.37658,0.37742]

x2=[1.25,1.26,1.27,1.28,1.29,1.30,1.31,1.32,1.33,1.34,1.35]
y2=[0.36531,0.36420,0.36105,0.35765,0.35143,0.35025,0.32884,0.35074,0.35123,0.35578,0.35930]

f=plt.figure()
f.set_figwidth(14)
f.set_figheight(8)

plt.xlabel('hyperparameter q')
plt.ylabel('validation loss')

plt.plot(x,y,'-o',color='b',label='increament rate=0.25')
plt.plot(x1,y1,'-o',color='g',label='increament rate=0.05')
plt.plot(x2,y2,'-o',color='r',label='increament rate=0.01')

plt.title('change of loss metric with respect to q')
plt.legend()


plt.show()
